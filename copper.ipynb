# %%
import pandas as pd

# %%
excelfile= pd.read_excel("D:/DATA_SCIENCE/Industrial-Copper-Modeling-/Copper_DataSet.xlsx")

# %%
excelfile.to_csv("copper.csv",index=False)

# %%
df=pd.read_csv("D:/DATA_SCIENCE/Industrial-Copper-Modeling-/copper.csv")
df
# Out:
# C:\Users\K R Bharath\AppData\Local\Temp\ipykernel_13900\2970036390.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("D:/DATA_SCIENCE/Industrial-Copper-Modeling-/copper.csv")
#                                           id   item_date       quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0           54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0          768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0          386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0          202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0          785.526262
# ...                                      ...         ...                 ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0  102.48242162880622
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0  208.08646861152863
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0  4.2355935684967845
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0               -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0  406.68653838450405
#
#           customer  country status item type  application  thickness   width  \
# 0       30156308.0     28.0    Won         W         10.0       2.00  1500.0
# 1       30202938.0     25.0    Won         W         41.0       0.80  1210.0
# 2       30153963.0     30.0    Won        WI         28.0       0.38   952.0
# 3       30349574.0     32.0    Won         S         59.0       2.30  1317.0
# 4       30211560.0     28.0    Won         W         10.0       4.00  2000.0
# ...            ...      ...    ...       ...          ...        ...     ...
# 181668  30200854.0     25.0    Won         W         41.0       0.96  1220.0
# 181669  30200854.0     25.0    Won         W         41.0       0.95  1500.0
# 181670  30200854.0     25.0    Won         W         41.0       0.71  1250.0
# 181671  30200854.0     25.0    Won         W         41.0       0.85  1250.0
# 181672  30200854.0     25.0    Won         W         41.0       0.71  1240.0
#
#                                     material_ref  product_ref  delivery date  \
# 0                                    DEQ1 S460MC   1670798778     20210701.0
# 1       0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                       S0380700       628377     20210101.0
# 3                        DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                                2_S275JR+AR-CL1       640665     20210301.0
# ...                                          ...          ...            ...
# 181668  0000000000000000000000000000000001000777    164141591     20200701.0
# 181669  0000000000000000000000000000000001000227    164141591     20200701.0
# 181670  0000000000000000000000000000000001004216    164141591     20200701.0
# 181671  0000000000000000000000000000000001001149    164141591     20200701.0
# 181672  0000000000000000000000000000000001005439    164141591     20200701.0
#
#         selling_price
# 0              854.00
# 1             1047.00
# 2              644.33
# 3              768.00
# 4              577.00
# ...               ...
# 181668         591.00
# 181669         589.00
# 181670         619.00
# 181671         601.00
# 181672         607.00
#
# [181673 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['id', 'item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'delivery date', 'selling_price'],
#       dtype='object')

# %%
df.shape
# Out:
# (181673, 14)

# %%
df.isnull().sum()
# Out:
# id                   2
# item_date            1
# quantity tons        0
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        1
# selling_price        1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
df['item_date']=pd.to_datetime(df['item_date'],format='%Y%m%d',errors='coerce').dt.date
df['quantity tons']=pd.to_numeric(df['quantity tons'],errors='coerce')
df['delivery date']=pd.to_datetime(df['delivery date'],format='%Y%m%d',errors='coerce').dt.date

# %%
# Convert columns to datetime
df['item_date'] = pd.to_datetime(df['item_date'])
df['delivery date']=pd.to_datetime(df['delivery date'])
# Calculate delivery time taken in days
df['delivery_time_taken']=(df['item_date']-df['delivery date']).abs().dt.days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   181671 non-null  object
#  1   item_date            181670 non-null  datetime64[ns]
#  2   quantity tons        181672 non-null  float64
#  3   customer             181672 non-null  float64
#  4   country              181645 non-null  float64
#  5   status               181671 non-null  object
#  6   item type            181673 non-null  object
#  7   application          181649 non-null  float64
#  8   thickness            181672 non-null  float64
#  9   width                181673 non-null  float64
#  10  material_ref         103754 non-null  object
#  11  product_ref          181673 non-null  int64
#  12  delivery date        181670 non-null  datetime64[ns]
#  13  selling_price        181672 non-null  float64
#  14  delivery_time_taken  181667 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(1), object(4)
# memory usage: 20.8+ MB

# %%
df.drop(['material_ref','id'],axis=1,inplace=True)

# %%
df
# Out:
#         item_date  quantity tons    customer  country status item type  \
# 0      2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1      2021-04-01     768.024839  30202938.0     25.0    Won         W
# 2      2021-04-01     386.127949  30153963.0     30.0    Won        WI
# 3      2021-04-01     202.411065  30349574.0     32.0    Won         S
# 4      2021-04-01     785.526262  30211560.0     28.0    Won         W
# ...           ...            ...         ...      ...    ...       ...
# 181668 2020-07-02     102.482422  30200854.0     25.0    Won         W
# 181669 2020-07-02     208.086469  30200854.0     25.0    Won         W
# 181670 2020-07-02       4.235594  30200854.0     25.0    Won         W
# 181671 2020-07-02   -2000.000000  30200854.0     25.0    Won         W
# 181672 2020-07-02     406.686538  30200854.0     25.0    Won         W
#
#         application  thickness   width  product_ref delivery date  \
# 0              10.0       2.00  1500.0   1670798778    2021-07-01
# 1              41.0       0.80  1210.0   1668701718    2021-04-01
# 2              28.0       0.38   952.0       628377    2021-01-01
# 3              59.0       2.30  1317.0   1668701718    2021-01-01
# 4              10.0       4.00  2000.0       640665    2021-03-01
# ...             ...        ...     ...          ...           ...
# 181668         41.0       0.96  1220.0    164141591    2020-07-01
# 181669         41.0       0.95  1500.0    164141591    2020-07-01
# 181670         41.0       0.71  1250.0    164141591    2020-07-01
# 181671         41.0       0.85  1250.0    164141591    2020-07-01
# 181672         41.0       0.71  1240.0    164141591    2020-07-01
#
#         selling_price  delivery_time_taken
# 0              854.00                 91.0
# 1             1047.00                  0.0
# 2              644.33                 90.0
# 3              768.00                 90.0
# 4              577.00                 31.0
# ...               ...                  ...
# 181668         591.00                  1.0
# 181669         589.00                  1.0
# 181670         619.00                  1.0
# 181671         601.00                  1.0
# 181672         607.00                  1.0
#
# [181673 rows x 13 columns]

# %%
# Check for negative values in numeric columns
numeric_columns=df.select_dtypes(include=['int64','float64'])
negative_values=numeric_columns[numeric_columns<=0].any()
print(negative_values)
# Out:
# quantity tons           True
# customer               False
# country                False
# application            False
# thickness              False
# width                  False
# product_ref            False
# selling_price           True
# delivery_time_taken    False
# dtype: bool

# %%
# "quantity tons" and "selling_price" have negative values, so we will replace the negative values with abs
df['quantity tons']=df['quantity tons'].apply(lambda x: -1*x if x<=0 else x)
df['selling_price']=df['selling_price'].apply(lambda x: -1*x if x<=0 else x)

# %%
df.isnull().sum()
# Out:
# item_date               3
# quantity tons           1
# customer                1
# country                28
# status                  2
# item type               0
# application            24
# thickness               1
# width                   0
# product_ref             0
# delivery date           3
# selling_price           1
# delivery_time_taken     6
# dtype: int64

# %%
# replacing the null values in "categorical columns" with the "mode" of that column
df['item_date']=df['item_date'].fillna(df['item_date'].mode().iloc[0])
df['status']=df['status'].fillna(df['status'].mode().iloc[0])
df['delivery date']=df['delivery date'].fillna(df['delivery date'].mode().iloc[0])

# %%
# replacing the null values in "continuous columns" with the "median" of that column
df['quantity tons']=df['quantity tons'].fillna(df['quantity tons'].median())
df['customer']=df['customer'].fillna(df['customer'].median())
df['country']=df['country'].fillna(df['country'].median())
df['application']=df['application'].fillna(df['application'].median())
df['thickness']=df['thickness'].fillna(df['thickness'].median())
df['selling_price']=df['selling_price'].fillna(df['selling_price'].median())
df['delivery_time_taken']=df['delivery_time_taken'].fillna(df['delivery_time_taken'].median())

# %%
df.isnull().sum()
# Out:
# item_date              0
# quantity tons          0
# customer               0
# country                0
# status                 0
# item type              0
# application            0
# thickness              0
# width                  0
# product_ref            0
# delivery date          0
# selling_price          0
# delivery_time_taken    0
# dtype: int64

# %%
df.nunique()
# Out:
# item_date                 250
# quantity tons          181673
# customer                 1169
# country                    17
# status                      9
# item type                   7
# application                30
# thickness                 594
# width                    1386
# product_ref                33
# delivery date              26
# selling_price            9792
# delivery_time_taken       229
# dtype: int64

# %%
df['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable'], dtype=object)

# %%
#encoding status columns using mapping since we need meaningful numbers
df['status']=df['status'].map({'Won':1,'Draft':2,'To be approved':3,'Lost':0,'Not lost for AM':4,'Wonderful':5,'Revised':6,'Offered':7,'Offerable':8})

# %%
df['item type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['item type']=LabelEncoder().fit_transform(df['item type'])

# %%
df['item type'].unique()
# Out:
# array([5, 6, 3, 1, 2, 0, 4])

# %%
df.to_csv("Industrial_Copper.csv",index=False)

# %%
df=pd.read_csv("Industrial_Copper.csv")

# %%
df1=df.copy()

# %%
from scipy.stats import skew

# %%
for col in ['quantity tons', 'customer', 'country', 'application', 'thickness', 'width', 'product_ref','selling_price','delivery_time_taken']:
    print(f'skewness of {col} is {skew(df1[col])}')
# Out:
# skewness of quantity tons is 424.68730994560605
# skewness of customer is 86.9845901502091
# skewness of country is 0.7538286488466676
# skewness of application is 0.7245583983073829
# skewness of thickness is 303.4450657126513
# skewness of width is 0.37459367901082125
# skewness of product_ref is 1.0152071910463223
# skewness of selling_price is 301.3855996606937
# skewness of delivery_time_taken is 0.46972996509615955

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# function for box plot, hist plot, violin plot
def plot(df,column):
    plt.figure(figsize=(20,5))

    plt.subplot(1,3,1)
    sns.histplot(data= df1,x=column,kde=True,bins=30,color='salmon')
    plt.title(f'Distribution Plot for {column}')
    plt.show

    plt.subplot(1,3,2)
    sns.boxplot(data= df1,x=column,color='green')
    plt.title(f'Box Plot for {column}')
    plt.show

    plt.subplot(1,3,3)
    sns.violinplot(data= df1,x=column,color='indigo')
    plt.title(f'Violin Plot for {column}')
    plt.show

# %%
# plotting to check skew
for col in ['quantity tons', 'customer', 'country', 'application', 'thickness', 'width', 'product_ref','selling_price','delivery_time_taken']:
    plot(df1,col)
# Out:
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import numpy as np

# %%
#Applying log transformation
df1['quantity_tons_log'] = np.log(df1['quantity tons'])

# %%
df1['thickness_log'] = np.log(df1['thickness'])

# %%
df1['selling_price_log'] = np.log(df1['selling_price']+1)

# %%
df1.drop(columns=['quantity tons','thickness','selling_price'],inplace=True)

# %%
df1
# Out:
#          item_date    customer  country  status  item type  application  \
# 0       2021-04-01  30156308.0     28.0       1          5         10.0
# 1       2021-04-01  30202938.0     25.0       1          5         41.0
# 2       2021-04-01  30153963.0     30.0       1          6         28.0
# 3       2021-04-01  30349574.0     32.0       1          3         59.0
# 4       2021-04-01  30211560.0     28.0       1          5         10.0
# ...            ...         ...      ...     ...        ...          ...
# 181668  2020-07-02  30200854.0     25.0       1          5         41.0
# 181669  2020-07-02  30200854.0     25.0       1          5         41.0
# 181670  2020-07-02  30200854.0     25.0       1          5         41.0
# 181671  2020-07-02  30200854.0     25.0       1          5         41.0
# 181672  2020-07-02  30200854.0     25.0       1          5         41.0
#
#          width  product_ref delivery date  delivery_time_taken  \
# 0       1500.0   1670798778    2021-07-01                 91.0
# 1       1210.0   1668701718    2021-04-01                  0.0
# 2        952.0       628377    2021-01-01                 90.0
# 3       1317.0   1668701718    2021-01-01                 90.0
# 4       2000.0       640665    2021-03-01                 31.0
# ...        ...          ...           ...                  ...
# 181668  1220.0    164141591    2020-07-01                  1.0
# 181669  1500.0    164141591    2020-07-01                  1.0
# 181670  1250.0    164141591    2020-07-01                  1.0
# 181671  1250.0    164141591    2020-07-01                  1.0
# 181672  1240.0    164141591    2020-07-01                  1.0
#
#         quantity_tons_log  thickness_log  selling_price_log
# 0                3.991779       0.693147           6.751101
# 1                6.643822      -0.223144           6.954639
# 2                5.956169      -0.967584           6.469762
# 3                5.310301       0.832909           6.645091
# 4                6.666354       1.386294           6.359574
# ...                   ...            ...                ...
# 181668           4.629691      -0.040822           6.383507
# 181669           5.337954      -0.051293           6.380123
# 181670           1.443523      -0.342490           6.429719
# 181671           7.600902      -0.162519           6.400257
# 181672           6.008043      -0.342490           6.410175
#
# [181673 rows x 13 columns]

# %%
# plotting to check skew after log transformation
for col in ['quantity_tons_log', 'customer', 'country', 'application', 'thickness_log', 'width', 'product_ref','selling_price_log','delivery_time_taken']:
    plot(df1,col)
# Out:
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1
# Out:
#          item_date    customer  country  status  item type  application  \
# 0       2021-04-01  30156308.0     28.0       1          5         10.0
# 1       2021-04-01  30202938.0     25.0       1          5         41.0
# 2       2021-04-01  30153963.0     30.0       1          6         28.0
# 3       2021-04-01  30349574.0     32.0       1          3         59.0
# 4       2021-04-01  30211560.0     28.0       1          5         10.0
# ...            ...         ...      ...     ...        ...          ...
# 181668  2020-07-02  30200854.0     25.0       1          5         41.0
# 181669  2020-07-02  30200854.0     25.0       1          5         41.0
# 181670  2020-07-02  30200854.0     25.0       1          5         41.0
# 181671  2020-07-02  30200854.0     25.0       1          5         41.0
# 181672  2020-07-02  30200854.0     25.0       1          5         41.0
#
#          width  product_ref delivery date  delivery_time_taken  \
# 0       1500.0   1670798778    2021-07-01                 91.0
# 1       1210.0   1668701718    2021-04-01                  0.0
# 2        952.0       628377    2021-01-01                 90.0
# 3       1317.0   1668701718    2021-01-01                 90.0
# 4       2000.0       640665    2021-03-01                 31.0
# ...        ...          ...           ...                  ...
# 181668  1220.0    164141591    2020-07-01                  1.0
# 181669  1500.0    164141591    2020-07-01                  1.0
# 181670  1250.0    164141591    2020-07-01                  1.0
# 181671  1250.0    164141591    2020-07-01                  1.0
# 181672  1240.0    164141591    2020-07-01                  1.0
#
#         quantity_tons_log  thickness_log  selling_price_log
# 0                3.991779       0.693147           6.751101
# 1                6.643822      -0.223144           6.954639
# 2                5.956169      -0.967584           6.469762
# 3                5.310301       0.832909           6.645091
# 4                6.666354       1.386294           6.359574
# ...                   ...            ...                ...
# 181668           4.629691      -0.040822           6.383507
# 181669           5.337954      -0.051293           6.380123
# 181670           1.443523      -0.342490           6.429719
# 181671           7.600902      -0.162519           6.400257
# 181672           6.008043      -0.342490           6.410175
#
# [181673 rows x 13 columns]

# %%
# function to remove outliers using the IQR method
def remove_outliers(df,column):
    Q1= df[column].quantile(0.25)
    Q3= df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_limit=Q1-1.5*IQR
    upper_limit=Q3+1.5*IQR
    df=df[(df[column]>=lower_limit) & (df[column]<=upper_limit)]
    return df

# %%
#apply the IQR method to continous column
continous_column=['quantity_tons_log', 'thickness_log', 'width','selling_price_log']
for col in continous_column:
    df1=remove_outliers(df1,col)

# %%
#check the dataframe after removing the outliers
print(f'Dataframe after the removal of outliers:{df1.shape}')
# Out:
# Dataframe after the removal of outliers:(163946, 13)

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1
# Out:
#          item_date    customer  country  status  item type  application  \
# 0       2021-04-01  30156308.0     28.0       1          5         10.0
# 1       2021-04-01  30202938.0     25.0       1          5         41.0
# 2       2021-04-01  30153963.0     30.0       1          6         28.0
# 3       2021-04-01  30349574.0     32.0       1          3         59.0
# 4       2021-04-01  30202938.0     25.0       1          5         41.0
# ...            ...         ...      ...     ...        ...          ...
# 163941  2020-07-02  30200854.0     25.0       1          5         41.0
# 163942  2020-07-02  30200854.0     25.0       1          5         41.0
# 163943  2020-07-02  30200854.0     25.0       1          5         41.0
# 163944  2020-07-02  30200854.0     25.0       1          5         41.0
# 163945  2020-07-02  30200854.0     25.0       1          5         41.0
#
#          width  product_ref delivery date  delivery_time_taken  \
# 0       1500.0   1670798778    2021-07-01                 91.0
# 1       1210.0   1668701718    2021-04-01                  0.0
# 2        952.0       628377    2021-01-01                 90.0
# 3       1317.0   1668701718    2021-01-01                 90.0
# 4       1265.0   1668701718    2021-04-01                  0.0
# ...        ...          ...           ...                  ...
# 163941  1240.0    164141591    2020-07-01                  1.0
# 163942  1220.0    164141591    2020-07-01                  1.0
# 163943  1500.0    164141591    2020-07-01                  1.0
# 163944  1250.0    164141591    2020-07-01                  1.0
# 163945  1240.0    164141591    2020-07-01                  1.0
#
#         quantity_tons_log  thickness_log  selling_price_log
# 0                3.991779       0.693147           6.751101
# 1                6.643822      -0.223144           6.954639
# 2                5.956169      -0.967584           6.469762
# 3                5.310301       0.832909           6.645091
# 4                5.419608       0.405465           6.891626
# ...                   ...            ...                ...
# 163941           4.670802      -0.040822           6.401917
# 163942           4.629691      -0.040822           6.383507
# 163943           5.337954      -0.051293           6.380123
# 163944           1.443523      -0.342490           6.429719
# 163945           6.008043      -0.342490           6.410175
#
# [163946 rows x 13 columns]

# %%
# plotting to check after log transformation skew and outliers removal 
for col in ['quantity_tons_log', 'thickness_log', 'width','selling_price_log']:
    plot(df1,col)
# Out:
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Annaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Checking correlation
correlation_matrix=df1[['quantity_tons_log', 'customer', 'country', 'application', 'thickness_log', 'width', 'product_ref','selling_price_log','delivery_time_taken']].corr()
plt.figure(figsize=(12,5))
heatmap=sns.heatmap(correlation_matrix,annot=True,fmt=".2f",cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\annaconda\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\annaconda\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\annaconda\lib\site-packages (from xgboost) (1.11.4)

# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\annaconda\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\annaconda\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\annaconda\lib\site-packages (from xgboost) (1.11.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,auc,roc_curve,confusion_matrix,classification_report

from imblearn.combine import SMOTETomek
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier

# %%
df_class=df1.copy()

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163946 entries, 0 to 163945
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   item_date            163946 non-null  object
#  1   customer             163946 non-null  float64
#  2   country              163946 non-null  float64
#  3   status               163946 non-null  int64
#  4   item type            163946 non-null  int64
#  5   application          163946 non-null  float64
#  6   width                163946 non-null  float64
#  7   product_ref          163946 non-null  int64
#  8   delivery date        163946 non-null  object
#  9   delivery_time_taken  163946 non-null  float64
#  10  quantity_tons_log    163946 non-null  float64
#  11  thickness_log        163946 non-null  float64
#  12  selling_price_log    163946 non-null  float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 16.3+ MB

# %%
#filter the status column, we need only won and lost values
df_class_status= df_class[(df_class['status']==1) | (df_class['status']==0)]

# %%
df_class_status
# Out:
#          item_date    customer  country  status  item type  application  \
# 0       2021-04-01  30156308.0     28.0       1          5         10.0
# 1       2021-04-01  30202938.0     25.0       1          5         41.0
# 2       2021-04-01  30153963.0     30.0       1          6         28.0
# 3       2021-04-01  30349574.0     32.0       1          3         59.0
# 4       2021-04-01  30202938.0     25.0       1          5         41.0
# ...            ...         ...      ...     ...        ...          ...
# 163941  2020-07-02  30200854.0     25.0       1          5         41.0
# 163942  2020-07-02  30200854.0     25.0       1          5         41.0
# 163943  2020-07-02  30200854.0     25.0       1          5         41.0
# 163944  2020-07-02  30200854.0     25.0       1          5         41.0
# 163945  2020-07-02  30200854.0     25.0       1          5         41.0
#
#          width  product_ref delivery date  delivery_time_taken  \
# 0       1500.0   1670798778    2021-07-01                 91.0
# 1       1210.0   1668701718    2021-04-01                  0.0
# 2        952.0       628377    2021-01-01                 90.0
# 3       1317.0   1668701718    2021-01-01                 90.0
# 4       1265.0   1668701718    2021-04-01                  0.0
# ...        ...          ...           ...                  ...
# 163941  1240.0    164141591    2020-07-01                  1.0
# 163942  1220.0    164141591    2020-07-01                  1.0
# 163943  1500.0    164141591    2020-07-01                  1.0
# 163944  1250.0    164141591    2020-07-01                  1.0
# 163945  1240.0    164141591    2020-07-01                  1.0
#
#         quantity_tons_log  thickness_log  selling_price_log
# 0                3.991779       0.693147           6.751101
# 1                6.643822      -0.223144           6.954639
# 2                5.956169      -0.967584           6.469762
# 3                5.310301       0.832909           6.645091
# 4                5.419608       0.405465           6.891626
# ...                   ...            ...                ...
# 163941           4.670802      -0.040822           6.401917
# 163942           4.629691      -0.040822           6.383507
# 163943           5.337954      -0.051293           6.380123
# 163944           1.443523      -0.342490           6.429719
# 163945           6.008043      -0.342490           6.410175
#
# [137647 rows x 13 columns]

# %%
df_class_status["status"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_class_status["status"].value_counts()
# Out:
# status
# 1    106545
# 0     31102
# Name: count, dtype: int64

# %%
df_class_status.columns
# Out:
# Index(['item_date', 'customer', 'country', 'status', 'item type',
#        'application', 'width', 'product_ref', 'delivery date',
#        'delivery_time_taken', 'quantity_tons_log', 'thickness_log',
#        'selling_price_log'],
#       dtype='object')

# %%
#independent column
x=df_class_status.drop(columns=['item_date','status','delivery date'],axis=1)
#dependent column
y= df_class_status['status']

# %%
x.shape,y.shape
# Out:
# ((137647, 10), (137647,))

# %%
y.value_counts()
# Out:
# status
# 1    106545
# 0     31102
# Name: count, dtype: int64

# %%
x_new,y_new=SMOTETomek().fit_resample(x,y)

# %%
x_new.shape,y_new.shape
# Out:
# ((210240, 10), (210240,))

# %%
y_new.value_counts()
# Out:
# status
# 1    105120
# 0    105120
# Name: count, dtype: int64

# %%
def best_algorithm_class(x_data,y_data,algorithm):
    x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.2,random_state=42)

    model= algorithm().fit(x_train,y_train)
    y_pred=model.predict(x_test)

    model_accuracy=accuracy_score(y_test,y_pred)

    metrics={"Algorithm":algorithm.__name__,"Accuracy_Score":model_accuracy}
    return metrics

# %%
print(best_algorithm_class(x_new,y_new,DecisionTreeClassifier))
print(best_algorithm_class(x_new,y_new,RandomForestClassifier))
print(best_algorithm_class(x_new,y_new,GradientBoostingClassifier))
print(best_algorithm_class(x_new,y_new,AdaBoostClassifier))
print(best_algorithm_class(x_new,y_new,ExtraTreesClassifier))
print(best_algorithm_class(x_new,y_new,XGBClassifier))
# Out:
# {'Algorithm': 'DecisionTreeClassifier', 'Accuracy_Score': 0.9594748858447488}
# {'Algorithm': 'RandomForestClassifier', 'Accuracy_Score': 0.979666095890411}
# {'Algorithm': 'GradientBoostingClassifier', 'Accuracy_Score': 0.8082191780821918}
# {'Algorithm': 'AdaBoostClassifier', 'Accuracy_Score': 0.7656487823439878}
# {'Algorithm': 'ExtraTreesClassifier', 'Accuracy_Score': 0.981687595129376}
# {'Algorithm': 'XGBClassifier', 'Accuracy_Score': 0.9344320776255708}

# %%
x_train, x_test, y_train, y_test = train_test_split(x_new, y_new, test_size = 0.20, random_state = 42)

parameter={'n_estimators':[50,100,200],'max_depth':[10,20,30],'min_samples_split':[2,4,6],'min_samples_leaf':[1,2,3]}

grid_search=GridSearchCV(estimator=ExtraTreesClassifier(random_state=42),param_grid=parameter,cv=5, scoring="accuracy",n_jobs=-1)

grid_search.fit(x_train,y_train)
print("Best Score: ", grid_search.best_score_,"Best Parameters: ", grid_search.best_params_)
# Out:
# Best Score:  0.9763068337876424 Best Parameters:  {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
x_train, x_test, y_train, y_test = train_test_split(x_new, y_new, test_size = 0.20, random_state = 42)
model1=ExtraTreesClassifier(max_depth= 30,min_samples_leaf= 1, min_samples_split= 2,n_estimators= 200).fit(x_train,y_train)
y_predict=model1.predict(x_test)
# Evaluation Metrics:
print("Accuracy Score: {:.4f}".format(accuracy_score(y_test, y_predict)))
print("Precision Score: {:.4f}".format(precision_score(y_test, y_predict)))
print("Recall Score: {:.4f}".format(recall_score(y_test, y_predict)))
print("F1 Score: {:.4f}".format(f1_score(y_test, y_predict)))
# Out:
# Accuracy Score: 0.9783
# Precision Score: 0.9911
# Recall Score: 0.9649
# F1 Score: 0.9778

# %%
#confusion matrix
print("Confusion matrix:")
print(confusion_matrix(y_test,y_predict))
# Out:
# Confusion matrix:
# [[21042   181]
#  [  730 20095]]

# %%
# classification report
print("Classification_report:")
print(classification_report(y_test,y_predict))
# Out:
# Classification_report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     21223
#            1       0.99      0.96      0.98     20825
#
#     accuracy                           0.98     42048
#    macro avg       0.98      0.98      0.98     42048
# weighted avg       0.98      0.98      0.98     42048

# %%
# Receiver Operating Characteristic (ROC) Curve
FP,TP,Threshold=roc_curve(y_test,y_predict)
print(FP)
print(TP)
print(Threshold)
# Out:
# [0.         0.00852848 1.        ]
# [0.         0.96494598 1.        ]
# [2 1 0]

# %%
# Area Under the Curve (AUC)
auc_curve = auc(x=FP, y=TP)
print("auc_curve: ", auc_curve)
# Out:
# auc_curve:  0.9782087475710258

# %%
#create a plot for ROC and AUC curve
roc_point={"ROC curve (area)":round(auc_curve,2)}
plt.plot(FP,TP,label=roc_point)
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.1])
plt.xlabel("False Positive")
plt.ylabel("True Positive")
plt.plot([0,1],[0,1],"k--")
plt.legend(loc="lower right")
plt.show()

# %%
import pickle

# %%
with open("Classifier_model.pkl","wb") as file:
    pickle.dump(model1,file)

# %%
x_new
# Out:
#           customer  country  item type  application   width  product_ref  \
# 0       30156308.0     28.0          5         10.0  1500.0   1670798778
# 1       30202938.0     25.0          5         41.0  1210.0   1668701718
# 2       30153963.0     30.0          6         28.0   952.0       628377
# 3       30349574.0     32.0          3         59.0  1317.0   1668701718
# 4       30202938.0     25.0          5         41.0  1265.0   1668701718
# ...            ...      ...        ...          ...     ...          ...
# 210235  30155929.0     25.0          3         41.0  1220.0       611993
# 210236  30197144.0     27.0          3         10.0  1250.0   1668701718
# 210237  30229528.0     84.0          5         41.0  1250.0       611993
# 210238  30148854.0     30.0          5         15.0  1250.0    164141591
# 210239  30197813.0     27.0          3         10.0  1495.0   1670798778
#
#         delivery_time_taken  quantity_tons_log  thickness_log  \
# 0                 91.000000           3.991779       0.693147
# 1                  0.000000           6.643822      -0.223144
# 2                 90.000000           5.956169      -0.967584
# 3                 90.000000           5.310301       0.832909
# 4                  0.000000           5.419608       0.405465
# ...                     ...                ...            ...
# 210235            35.691601           3.946180      -0.798508
# 210236           113.663442           3.576896      -0.123729
# 210237            66.000000           2.825744      -0.798508
# 210238            59.000000           3.496541       0.924151
# 210239            56.000000           4.896479       1.535829
#
#         selling_price_log
# 0                6.751101
# 1                6.954639
# 2                6.469762
# 3                6.645091
# 4                6.891626
# ...                   ...
# 210235           6.892267
# 210236           6.836005
# 210237           7.230559
# 210238           6.303499
# 210239           6.261452
#
# [210240 rows x 10 columns]

# %%
with open("Classifier_model.pkl","rb") as file:
    class_model=pickle.load(file)

classifier=class_model.predict(np.array([[30153963.0,30.0,6,28.0,952.000000,628377,91.000000,5.956169,-0.967584,6.469762]]))
if classifier[0]==1:
    print('Won')
else:
    print('Lose')
# Out:
# Won
# c:\Annaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but ExtraTreesClassifier was fitted with feature names
#   warnings.warn(

# %%
min_value= df1.min()
max_value= df1.max()
min_max_df=pd.concat([min_value,max_value],axis=1)
min_max_df.columns=["Minimum","Maximum"]

print(min_max_df)
# Out:
#                         Minimum       Maximum
# item_date            2020-07-02    2021-04-01
# customer                12458.0  2147483647.0
# country                    25.0         113.0
# status                        0             8
# item type                     0             6
# application                 2.0          99.0
# width                     700.0        1980.0
# product_ref              611733    1721130331
# delivery date        2019-04-01    2021-11-01
# delivery_time_taken         0.0         689.0
# quantity_tons_log     -0.321232      6.924498
# thickness_log         -1.714798      3.234749
# selling_price_log      5.991465      7.395722

# %%
#packages

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from xgboost import XGBRegressor

# %%
df_reg=df1.copy()
df_reg.head()
# Out:
#     item_date    customer  country  status  item type  application   width  \
# 0  2021-04-01  30156308.0     28.0       1          5         10.0  1500.0
# 1  2021-04-01  30202938.0     25.0       1          5         41.0  1210.0
# 2  2021-04-01  30153963.0     30.0       1          6         28.0   952.0
# 3  2021-04-01  30349574.0     32.0       1          3         59.0  1317.0
# 4  2021-04-01  30202938.0     25.0       1          5         41.0  1265.0
#
#    product_ref delivery date  delivery_time_taken  quantity_tons_log  \
# 0   1670798778    2021-07-01                 91.0           3.991779
# 1   1668701718    2021-04-01                  0.0           6.643822
# 2       628377    2021-01-01                 90.0           5.956169
# 3   1668701718    2021-01-01                 90.0           5.310301
# 4   1668701718    2021-04-01                  0.0           5.419608
#
#    thickness_log  selling_price_log
# 0       0.693147           6.751101
# 1      -0.223144           6.954639
# 2      -0.967584           6.469762
# 3       0.832909           6.645091
# 4       0.405465           6.891626

# %%
#independent
x1=df_reg.drop(['item_date','delivery date','selling_price_log'],axis=1)
#dependent
y1=df_reg['selling_price_log']

# %%
def best_algorithm_reg(df,algorithm):

    x=df_reg.drop(['item_date','delivery date','selling_price_log'],axis=1)
    y=df_reg['selling_price_log']

    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=42)
    model2=algorithm().fit(x_train,y_train)
    y_pred=model2.predict(x_test)

    r2=r2_score(y_test,y_pred)

    metrics={'Alogrithm':algorithm.__name__,'R2 Score':r2}
    return metrics

# %%
print(best_algorithm_reg(df_reg,LinearRegression))
print(best_algorithm_reg(df_reg,DecisionTreeRegressor))
print(best_algorithm_reg(df_reg,RandomForestRegressor))
print(best_algorithm_reg(df_reg,GradientBoostingRegressor))
print(best_algorithm_reg(df_reg,AdaBoostRegressor))
print(best_algorithm_reg(df_reg,ExtraTreesRegressor))
print(best_algorithm_reg(df_reg,XGBRegressor))
# Out:
# {'Alogrithm': 'LinearRegression', 'R2 Score': 0.38560280506840416}
# {'Alogrithm': 'DecisionTreeRegressor', 'R2 Score': 0.8472216833584477}
# {'Alogrithm': 'RandomForestRegressor', 'R2 Score': 0.9132457361561318}
# {'Alogrithm': 'GradientBoostingRegressor', 'R2 Score': 0.6348044588220965}
# {'Alogrithm': 'AdaBoostRegressor', 'R2 Score': 0.5088109938296896}
# {'Alogrithm': 'ExtraTreesRegressor', 'R2 Score': 0.9112769402185534}
# {'Alogrithm': 'XGBRegressor', 'R2 Score': 0.8114964342805163}

# %%
x_train, x_test, y_train, y_test = train_test_split(x_new, y_new, test_size = 0.20, random_state = 42)
model2=RandomForestRegressor(n_estimators=100,max_depth=30,min_samples_split=2,min_samples_leaf=1).fit(x_train,y_train)
y_predict=model2.predict(x_test)
# Evaluation Metrics:
print("MAE: {:.4f}".format(mean_absolute_error(y_test,y_predict)))
print("MSE: {:.4f}".format(mean_squared_error(y_test,y_predict)))
print("RMSE: {:.4f}".format(np.sqrt(mean_squared_error(y_test,y_predict))))
print("R2: {:.4f}".format(r2_score(y_test,y_predict)))
# Out:
# MAE: 0.0524
# MSE: 0.0195
# RMSE: 0.1395
# R2: 0.9221

# %%
x_train, x_test, y_train, y_test = train_test_split(x_new, y_new, test_size = 0.20, random_state = 42)
model3=RandomForestRegressor(n_estimators=100,max_depth=30,min_samples_split=4,min_samples_leaf=2).fit(x_train,y_train)
y_predict=model3.predict(x_test)
# Evaluation Metrics:
print("MAE: {:.4f}".format(mean_absolute_error(y_test,y_predict)))
print("MSE: {:.4f}".format(mean_squared_error(y_test,y_predict)))
print("RMSE: {:.4f}".format(np.sqrt(mean_squared_error(y_test,y_predict))))
print("R2: {:.4f}".format(r2_score(y_test,y_predict)))
# Out:
# MAE: 0.0592
# MSE: 0.0216
# RMSE: 0.1470
# R2: 0.9136

# %%
with open("Regressor_model.pkl","wb") as file:
    pickle.dump(model2,file)

# %%
x1
# Out:
#           customer  country  status  item type  application   width  \
# 0       30156308.0     28.0       1          5         10.0  1500.0
# 1       30202938.0     25.0       1          5         41.0  1210.0
# 2       30153963.0     30.0       1          6         28.0   952.0
# 3       30349574.0     32.0       1          3         59.0  1317.0
# 4       30202938.0     25.0       1          5         41.0  1265.0
# ...            ...      ...     ...        ...          ...     ...
# 163941  30200854.0     25.0       1          5         41.0  1240.0
# 163942  30200854.0     25.0       1          5         41.0  1220.0
# 163943  30200854.0     25.0       1          5         41.0  1500.0
# 163944  30200854.0     25.0       1          5         41.0  1250.0
# 163945  30200854.0     25.0       1          5         41.0  1240.0
#
#         product_ref  delivery_time_taken  quantity_tons_log  thickness_log
# 0        1670798778                 91.0           3.991779       0.693147
# 1        1668701718                  0.0           6.643822      -0.223144
# 2            628377                 90.0           5.956169      -0.967584
# 3        1668701718                 90.0           5.310301       0.832909
# 4        1668701718                  0.0           5.419608       0.405465
# ...             ...                  ...                ...            ...
# 163941    164141591                  1.0           4.670802      -0.040822
# 163942    164141591                  1.0           4.629691      -0.040822
# 163943    164141591                  1.0           5.337954      -0.051293
# 163944    164141591                  1.0           1.443523      -0.342490
# 163945    164141591                  1.0           6.008043      -0.342490
#
# [163946 rows x 10 columns]

# %%
with open("Regressor_model.pkl","rb") as file:
    reg_model=pickle.load(file)

predict=reg_model.predict(np.array([[30156308.0,25.0,1,5,41.0,1210.0,1668701718,91.0,6.643822,-0.223144]]))
predicted_selling_price=np.exp(predict[0])

print(f"Predicted Selling Price:{predicted_selling_price:.2f}")
# Out:
# Predicted Selling Price:2.36
# c:\Annaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
df1
# Out:
#          item_date    customer  country  status  item type  application  \
# 0       2021-04-01  30156308.0     28.0       1          5         10.0
# 1       2021-04-01  30202938.0     25.0       1          5         41.0
# 2       2021-04-01  30153963.0     30.0       1          6         28.0
# 3       2021-04-01  30349574.0     32.0       1          3         59.0
# 4       2021-04-01  30202938.0     25.0       1          5         41.0
# ...            ...         ...      ...     ...        ...          ...
# 163941  2020-07-02  30200854.0     25.0       1          5         41.0
# 163942  2020-07-02  30200854.0     25.0       1          5         41.0
# 163943  2020-07-02  30200854.0     25.0       1          5         41.0
# 163944  2020-07-02  30200854.0     25.0       1          5         41.0
# 163945  2020-07-02  30200854.0     25.0       1          5         41.0
#
#          width  product_ref delivery date  delivery_time_taken  \
# 0       1500.0   1670798778    2021-07-01                 91.0
# 1       1210.0   1668701718    2021-04-01                  0.0
# 2        952.0       628377    2021-01-01                 90.0
# 3       1317.0   1668701718    2021-01-01                 90.0
# 4       1265.0   1668701718    2021-04-01                  0.0
# ...        ...          ...           ...                  ...
# 163941  1240.0    164141591    2020-07-01                  1.0
# 163942  1220.0    164141591    2020-07-01                  1.0
# 163943  1500.0    164141591    2020-07-01                  1.0
# 163944  1250.0    164141591    2020-07-01                  1.0
# 163945  1240.0    164141591    2020-07-01                  1.0
#
#         quantity_tons_log  thickness_log  selling_price_log
# 0                3.991779       0.693147           6.751101
# 1                6.643822      -0.223144           6.954639
# 2                5.956169      -0.967584           6.469762
# 3                5.310301       0.832909           6.645091
# 4                5.419608       0.405465           6.891626
# ...                   ...            ...                ...
# 163941           4.670802      -0.040822           6.401917
# 163942           4.629691      -0.040822           6.383507
# 163943           5.337954      -0.051293           6.380123
# 163944           1.443523      -0.342490           6.429719
# 163945           6.008043      -0.342490           6.410175
#
# [163946 rows x 13 columns]

# %%
value=df1['product_ref'].unique()
sorted_value=sorted(value)
print(sorted_value)
# Out:
# [611733, 611993, 628117, 628377, 640405, 640665, 164141591, 164337175, 929423819, 1282007633, 1332077137, 1665572032, 1665572374, 1668701376, 1668701698, 1668701718, 1668701725, 1670798778, 1671863738, 1690738206, 1690738219, 1693867550, 1693867563, 1721130331]
